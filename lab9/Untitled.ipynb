# %%
from fft_analyse import fft_analyse

fft_analyse(
    image="samples/galia.png", 
    pattern="samples/galia_e.png",
    invert=True,
    cutoff_v=0.9
)

# %%
fft_analyse(
    image="samples/school.jpg", 
    pattern="samples/fish1.png",
    invert=False,
    cutoff_v=0.999
)

# %%
import numpy as np
import freetype
face = freetype.Face("fonts/arial.ttf")
face.set_char_size( 48*64 )
face.load_char('S')
bitmap = face.glyph.bitmap
np.array(bitmap)
# Out:
# array(<freetype.Bitmap object at 0x7f4872f22f28>, dtype=object)

# %%
import matplotlib.pyplot as plt
import ocr
a = ocr.load_font_patterns("a", 16)["a"]
plt.imshow(a, cmap='gray', vmin=0, vmax=255)

# %% [markdown]
# ######
